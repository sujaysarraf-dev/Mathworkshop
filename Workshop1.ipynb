# %% [markdown]
# <a href="https://colab.research.google.com/github/sujaysarraf-dev/Mathworkshop/blob/main/Workshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
length = 10 #variable1
width = 5 #variable2
area = length * width #This is called an expression
print(area)
# Out:
# 50

# %%
hrs = input("Enter Hours:")
h = float(hrs)
rate = input("Enter the rate per hour:")
r = float(rate)
if h<=10:
  pay=h*r
else:
  pay=40*r+(h-40)*r*1.5
print(pay)
# Out:
# Enter Hours:45
# Enter the rate per hour:10.50
# 498.75

# %%
def greeting(name):
  print("welcome to python" +" "+ name)
greeting("Sujay")
# Out:
# welcome to python Sujay

# %%
def area_of_triangle(b, h):
  return b*h/2
area = area_of_triangle(4, 8)
print("area of traingle is: " + str(area))
# Out:
# area of traingle is: 16.0

# %%
def order_numbers(number1, number2):
  if number2 > number1:
     return number1,number2
  else:
    return number2,number1
smaller, bigger = order_numbers(100, 99)
print(smaller, bigger)
# Out:
# 99 100
